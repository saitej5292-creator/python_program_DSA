# %% [markdown]
# Introduction to PY:

# %% [markdown]
# -Python is interpreted , object oriented, high level
#
#     - Data Types:
#         ○ List - mutable
#         ○ Tuple - immutable
#     - Print function used to display the output
#         ○ Text- str
#         ○ Numeric-int,float,complex
#         ○ Mapping-dict
#         ○ Sequence-list,tuple,range
#         ○ Set-set,frozenset
#         ○ Boolean-bool
#         ○ Binary-bytes,bytearray,memoryview
#     - Operators
#         ○ Identity(new)-is,is not
#         ○ Membership-In, not in
# Write the program using arithmatic operator , logical operator, comparioson operator and assignment operator to create a strudent grade calculator.
